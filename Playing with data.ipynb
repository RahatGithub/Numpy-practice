# %%
import numpy as np
import csv

# %%
with open('Data/data.csv', newline='') as file:
    csv_reader = csv.reader(file)
    header = next(csv_reader)
    
    arr = np.array([e for e in csv_reader])

# %%
indices = np.where(arr=='79')
indices
# Out:
# (array([78], dtype=int64), array([0], dtype=int64))

# %%
arr
# Out:
# array([['1', '6.989439089576919', '0.001149891774891775',
#         '80.85615015029907', '0.0'],
#        ['2', '6.81408978334237', '0.0028070887445887445',
#         '6.786587744951248', '0.0048828125'],
#        ['3', '6.516961602937608', '0.007389745670995671',
#         '6.511988192796707', '0.01171875'],
#        ['4', '6.149220388689082', '0.0149316829004329',
#         '10.39312145113945', '0.005859375'],
#        ['5', '5.76953978455944', '0.027580492424242424',
#         '5.9389775693416595', '0.015625'],
#        ['6', '5.433582451436426', '0.044067911255411256',
#         '6.068404287099838', '0.017578125'],
#        ['7', '5.1455368231901355', '0.06579748376623376',
#         '5.5051901042461395', '0.04164162662345916'],
#        ['8', '4.888668309300493', '0.08781452922077922',
#         '5.755573868751526', '0.05629006412345916'],
#        ['9', '4.653337243831519', '0.1116409632034632',
#         '6.045258790254593', '0.04359475162345916'],
# ...
